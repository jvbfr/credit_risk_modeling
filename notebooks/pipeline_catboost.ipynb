# %%
## Pipeline com Catboost

# %%
import pandas as pd
import numpy as np
import optuna

from sklearn.model_selection import TimeSeriesSplit
from sklearn.metrics import roc_auc_score
from scipy import stats
from catboost import CatBoostClassifier

# --- Funções e Configurações Iniciais ---

def calcular_ks_scipy(y_true: np.ndarray, y_pred_proba: np.ndarray) -> float:
    """Calcula a estatística KS (Kolmogorov-Smirnov)."""
    prob_bads = y_pred_proba[y_true == 1]
    prob_goods = y_pred_proba[y_true == 0]
    if len(prob_bads) == 0 or len(prob_goods) == 0:
        return 0.0
    ks_statistic, _ = stats.ks_2samp(prob_bads, prob_goods)
    return ks_statistic

# --- Carregamento dos Dados ---
try:
    treino_df = pd.read_csv("../data/dev/train.csv", index_col=0)
    validacao_df = pd.read_csv("../data/dev/val.csv", index_col=0)
    teste_oot_df = pd.read_csv("../data/dev/test.csv", index_col=0)

    dev_df = pd.concat([treino_df, validacao_df], ignore_index=True)
    
    TARGET = 'target'
    FEATURES = [col for col in dev_df.columns if col not in [
        TARGET, 'data_originacao', 'id_contrato', 'custo_fn', 'custo_fp'
    ]]

    X_dev = dev_df[FEATURES]
    y_dev = dev_df[TARGET]
    
    X_oot = teste_oot_df[FEATURES]
    y_oot = teste_oot_df[TARGET]

except FileNotFoundError as e:
    print(f"Problema com os dados: {e}. Verifique os caminhos dos arquivos.")
    exit()

# --- Identificação de Features Categóricas para o CatBoost ---
categorical_features_indices = [i for i, col in enumerate(X_dev.columns) if X_dev[col].dtype == 'object']
print(f"Features categóricas identificadas: {[X_dev.columns[i] for i in categorical_features_indices]}")
print("\n" + "="*80 + "\n")


# --- 1. DEFINIÇÃO DA FUNÇÃO OBJECTIVE PARA O OPTUNA ---

def objective(trial: optuna.Trial) -> float:
    """
    Função que o Optuna tentará otimizar.
    Ela treina um modelo CatBoost com os hiperparâmetros sugeridos pelo 'trial'
    e retorna o AUC médio da validação cruzada temporal.
    """
    # Espaço de busca dos hiperparâmetros
    params = {
        'objective': 'Logloss',
        'eval_metric': 'AUC',
        'iterations': 1500,  # Aumentamos um pouco o teto, pois o early stopping vai agir
        'verbose': 0,
        'random_seed': 42,
        'cat_features': categorical_features_indices,
        'allow_writing_files': False, # Desativa a criação de arquivos de log do catboost

        # Hiperparâmetros a serem otimizados pelo Optuna
        'learning_rate': trial.suggest_float('learning_rate', 0.01, 0.2, log=True),
        'depth': trial.suggest_int('depth', 4, 10),
        'l2_leaf_reg': trial.suggest_float('l2_leaf_reg', 1e-3, 30.0, log=True),
        'colsample_bylevel': trial.suggest_float('colsample_bylevel', 0.4, 1.0),
        'min_child_samples': trial.suggest_int('min_child_samples', 5, 100),
        'bootstrap_type': trial.suggest_categorical('bootstrap_type', ['Bayesian', 'Bernoulli', 'MVS']),
    }
    
    # Ajustes condicionais para o bootstrap_type 'Bernoulli'
    if params['bootstrap_type'] == 'Bernoulli':
        params['subsample'] = trial.suggest_float('subsample', 0.1, 1.0)

    tscv = TimeSeriesSplit(n_splits=5)
    fold_auc_scores = []

    for train_index, val_index in tscv.split(X_dev):
        X_train_fold, X_val_fold = X_dev.iloc[train_index], X_dev.iloc[val_index]
        y_train_fold, y_val_fold = y_dev.iloc[train_index], y_dev.iloc[val_index]

        model = CatBoostClassifier(**params)
        
        model.fit(
            X_train_fold, y_train_fold,
            eval_set=(X_val_fold, y_val_fold),
            early_stopping_rounds=50,
            verbose=False
        )
        
        preds = model.predict_proba(X_val_fold)[:, 1]
        auc_fold = roc_auc_score(y_val_fold, preds)
        fold_auc_scores.append(auc_fold)

    return np.mean(fold_auc_scores)

# --- 2. EXECUÇÃO DO ESTUDO DE OTIMIZAÇÃO ---

print("---" * 10 + " INICIANDO O TUNING DE HIPERPARÂMETROS COM OPTUNA " + "---" * 10)

# Criamos um "estudo", que gerencia o processo de otimização
study = optuna.create_study(direction='maximize')

# Iniciamos a otimização. O Optuna chamará a função 'objective' 100 vezes.
study.optimize(objective, n_trials=100, show_progress_bar=True)

print("\nOtimização concluída!")
print(f"Melhor valor de AUC na validação cruzada: {study.best_value:.4f}")
print("Melhores hiperparâmetros encontrados:")
print(study.best_params)
print("\n" + "="*80 + "\n")


# --- 3. TREINAMENTO DO MODELO FINAL COM OS MELHORES PARÂMETROS ---

print("---" * 10 + " TREINANDO MODELO FINAL OTIMIZADO E AVALIANDO NO OOT " + "---" * 10)

# Pegando os melhores parâmetros encontrados
best_params = study.best_params
# Adicionando parâmetros fixos
best_params.update({
    'iterations': 2000, # Aumentamos um pouco para o treino final
    'verbose': 200,
    'random_seed': 42,
    'cat_features': categorical_features_indices,
    'objective': 'Logloss',
    'eval_metric': 'AUC',
})


final_model_tuned = CatBoostClassifier(**best_params)

# Treinando com o dataset de desenvolvimento completo (treino + validação)
final_model_tuned.fit(X_dev, y_dev)


# --- 4. AVALIAÇÃO FINAL ---

y_oot_pred_proba_tuned = final_model_tuned.predict_proba(X_oot)[:, 1]

auc_oot_tuned = roc_auc_score(y_oot, y_oot_pred_proba_tuned)
ks_oot_tuned = calcular_ks_scipy(y_oot.values, y_oot_pred_proba_tuned)

print("\n" + "---" * 10 + " RESULTADO FINAL (OOT) - CatBoost Otimizado " + "---" * 10)
print(f">> Performance no Teste Out-of-Time: AUC = {auc_oot_tuned:.4f}, KS = {ks_oot_tuned:.4f}")
print("---" * 27)

print("\nComparativo com o modelo anterior (não otimizado):")
print("AUC OOT (sem tuning): 0.6579")
print("KS OOT (sem tuning):  0.2141")
# Out:
# [I 2025-06-26 10:12:12,583] A new study created in memory with name: no-name-306af55b-1c48-4cec-a130-ffefaf665c34
# Features categóricas identificadas: ['tipo_cliente', 'estado', 'qtd_contratos_anteriores_bin', 'total_parcelas_historicas_bin', 'qtd_atrasos_historicos_bin', 'qtd_antecipacoes_historicas_bin', 'taxa_atraso_historica_bin', 'taxa_antecipacao_historica_bin', 'max_atraso_dias_historico_bin', 'media_valor_financiado_anterior_bin', 'max_valor_financiado_anterior_bin', 'media_prazo_anterior_bin', 'max_prazo_anterior_bin', 'dias_desde_ultimo_contrato_bin', 'dias_como_cliente_bin', 'qtd_parcelas_em_aberto_bin', 'valor_total_em_aberto_bin']
#
# ================================================================================
#
# ------------------------------ INICIANDO O TUNING DE HIPERPARÂMETROS COM OPTUNA ------------------------------
#   0%|          | 0/100 [00:00<?, ?it/s]
# [I 2025-06-26 10:13:00,434] Trial 0 finished with value: 0.6427088482981062 and parameters: {'learning_rate': 0.02214216809047802, 'depth': 5, 'l2_leaf_reg': 1.2818031884122922, 'colsample_bylevel': 0.5682611095761476, 'min_child_samples': 50, 'bootstrap_type': 'Bayesian'}. Best is trial 0 with value: 0.6427088482981062.
# [I 2025-06-26 10:13:50,176] Trial 1 finished with value: 0.6329256031315174 and parameters: {'learning_rate': 0.16768495632456715, 'depth': 10, 'l2_leaf_reg': 6.35959507695476, 'colsample_bylevel': 0.9958648687181803, 'min_child_samples': 75, 'bootstrap_type': 'MVS'}. Best is trial 0 with value: 0.6427088482981062.
# [I 2025-06-26 10:14:13,723] Trial 2 finished with value: 0.6374600264628288 and parameters: {'learning_rate': 0.12182818459673328, 'depth': 7, 'l2_leaf_reg': 1.7008020208218673, 'colsample_bylevel': 0.48903681706352997, 'min_child_samples': 37, 'bootstrap_type': 'Bernoulli', 'subsample': 0.6039832627731663}. Best is trial 0 with value: 0.6427088482981062.
# [I 2025-06-26 10:14:53,561] Trial 3 finished with value: 0.642584298813284 and parameters: {'learning_rate': 0.0510883055161337, 'depth': 5, 'l2_leaf_reg': 0.17633747678067493, 'colsample_bylevel': 0.8365548085399241, 'min_child_samples': 19, 'bootstrap_type': 'MVS'}. Best is trial 0 with value: 0.6427088482981062.
# [I 2025-06-26 10:15:24,016] Trial 4 finished with value: 0.5977527127017008 and parameters: {'learning_rate': 0.10155782283304549, 'depth': 10, 'l2_leaf_reg': 0.0011138422414488144, 'colsample_bylevel': 0.742447775524443, 'min_child_samples': 83, 'bootstrap_type': 'Bayesian'}. Best is trial 0 with value: 0.6427088482981062.
# [I 2025-06-26 10:15:56,841] Trial 5 finished with value: 0.6278800571492396 and parameters: {'learning_rate': 0.09919924525096267, 'depth': 6, 'l2_leaf_reg': 0.02655648051709731, 'colsample_bylevel': 0.9646132776504228, 'min_child_samples': 67, 'bootstrap_type': 'Bayesian'}. Best is trial 0 with value: 0.6427088482981062.
# [I 2025-06-26 10:17:00,014] Trial 6 finished with value: 0.6479854694782855 and parameters: {'learning_rate': 0.0403163628298799, 'depth': 8, 'l2_leaf_reg': 6.456366247094656, 'colsample_bylevel': 0.502712843923536, 'min_child_samples': 60, 'bootstrap_type': 'MVS'}. Best is trial 6 with value: 0.6479854694782855.
# [I 2025-06-26 10:17:31,712] Trial 7 finished with value: 0.614187789031219 and parameters: {'learning_rate': 0.11513161657067132, 'depth': 10, 'l2_leaf_reg': 0.07311249050907011, 'colsample_bylevel': 0.47029535883980245, 'min_child_samples': 39, 'bootstrap_type': 'Bayesian'}. Best is trial 6 with value: 0.6479854694782855.
# [I 2025-06-26 10:18:49,600] Trial 8 finished with value: 0.6328707079304423 and parameters: {'learning_rate': 0.02295768448288444, 'depth': 6, 'l2_leaf_reg': 0.010980696800690368, 'colsample_bylevel': 0.9936454594612005, 'min_child_samples': 72, 'bootstrap_type': 'Bayesian'}. Best is trial 6 with value: 0.6479854694782855.
# [I 2025-06-26 10:19:09,763] Trial 9 finished with value: 0.6180653148892998 and parameters: {'learning_rate': 0.1786981992517231, 'depth': 5, 'l2_leaf_reg': 0.0041409858214400816, 'colsample_bylevel': 0.7772344622716554, 'min_child_samples': 42, 'bootstrap_type': 'MVS'}. Best is trial 6 with value: 0.6479854694782855.
# [I 2025-06-26 10:21:06,646] Trial 10 finished with value: 0.6367578163121064 and parameters: {'learning_rate': 0.010644705242066394, 'depth': 8, 'l2_leaf_reg': 19.079877147887455, 'colsample_bylevel': 0.6304278305753915, 'min_child_samples': 100, 'bootstrap_type': 'Bernoulli', 'subsample': 0.13323985719115394}. Best is trial 6 with value: 0.6479854694782855.
# [I 2025-06-26 10:21:48,535] Trial 11 finished with value: 0.6391654351482938 and parameters: {'learning_rate': 0.029124508163144946, 'depth': 4, 'l2_leaf_reg': 0.7328540542508343, 'colsample_bylevel': 0.5620004340636957, 'min_child_samples': 56, 'bootstrap_type': 'MVS'}. Best is trial 6 with value: 0.6479854694782855.
# [I 2025-06-26 10:22:41,606] Trial 12 finished with value: 0.6441986562545037 and parameters: {'learning_rate': 0.04487078288798723, 'depth': 8, 'l2_leaf_reg': 1.9328056709373578, 'colsample_bylevel': 0.4184087498128251, 'min_child_samples': 10, 'bootstrap_type': 'Bayesian'}. Best is trial 6 with value: 0.6479854694782855.
# [I 2025-06-26 10:23:41,094] Trial 13 finished with value: 0.646052976636293 and parameters: {'learning_rate': 0.047034997847541775, 'depth': 8, 'l2_leaf_reg': 28.067662867953253, 'colsample_bylevel': 0.4079654203593489, 'min_child_samples': 7, 'bootstrap_type': 'MVS'}. Best is trial 6 with value: 0.6479854694782855.
# [I 2025-06-26 10:24:32,400] Trial 14 finished with value: 0.6499844506443081 and parameters: {'learning_rate': 0.06188132458197773, 'depth': 8, 'l2_leaf_reg': 22.770939762940063, 'colsample_bylevel': 0.4197307506713254, 'min_child_samples': 19, 'bootstrap_type': 'MVS'}. Best is trial 14 with value: 0.6499844506443081.
# [I 2025-06-26 10:25:24,451] Trial 15 finished with value: 0.6388566746236182 and parameters: {'learning_rate': 0.06419649491816753, 'depth': 9, 'l2_leaf_reg': 6.907966498658175, 'colsample_bylevel': 0.6513582744505453, 'min_child_samples': 25, 'bootstrap_type': 'MVS'}. Best is trial 14 with value: 0.6499844506443081.
# [I 2025-06-26 10:26:11,515] Trial 16 finished with value: 0.6440931246498077 and parameters: {'learning_rate': 0.07077768919079087, 'depth': 7, 'l2_leaf_reg': 6.6088798830796565, 'colsample_bylevel': 0.5153059910171628, 'min_child_samples': 57, 'bootstrap_type': 'MVS'}. Best is trial 14 with value: 0.6499844506443081.
# [I 2025-06-26 10:27:11,460] Trial 17 finished with value: 0.6377229121915485 and parameters: {'learning_rate': 0.03259810102798194, 'depth': 9, 'l2_leaf_reg': 0.40239655772284416, 'colsample_bylevel': 0.5825964502342323, 'min_child_samples': 27, 'bootstrap_type': 'MVS'}. Best is trial 14 with value: 0.6499844506443081.
# [I 2025-06-26 10:29:04,762] Trial 18 finished with value: 0.6465377080435675 and parameters: {'learning_rate': 0.01586860673961171, 'depth': 9, 'l2_leaf_reg': 11.509952293974056, 'colsample_bylevel': 0.40055080281697414, 'min_child_samples': 93, 'bootstrap_type': 'Bernoulli', 'subsample': 0.9988037187065286}. Best is trial 14 with value: 0.6499844506443081.
# [I 2025-06-26 10:29:46,794] Trial 19 finished with value: 0.6459754206645344 and parameters: {'learning_rate': 0.07017313951244973, 'depth': 8, 'l2_leaf_reg': 4.5540121431821285, 'colsample_bylevel': 0.4754869819137184, 'min_child_samples': 65, 'bootstrap_type': 'MVS'}. Best is trial 14 with value: 0.6499844506443081.
# [I 2025-06-26 10:31:08,977] Trial 20 finished with value: 0.6400616517495272 and parameters: {'learning_rate': 0.03517505900970528, 'depth': 7, 'l2_leaf_reg': 0.2542742083561746, 'colsample_bylevel': 0.6767141673431654, 'min_child_samples': 45, 'bootstrap_type': 'MVS'}. Best is trial 14 with value: 0.6499844506443081.
# [I 2025-06-26 10:32:48,343] Trial 21 finished with value: 0.634588205180117 and parameters: {'learning_rate': 0.01263291345499574, 'depth': 9, 'l2_leaf_reg': 13.84371509214877, 'colsample_bylevel': 0.40110141709436636, 'min_child_samples': 99, 'bootstrap_type': 'Bernoulli', 'subsample': 0.9871611551330212}. Best is trial 14 with value: 0.6499844506443081.
# [I 2025-06-26 10:34:29,138] Trial 22 finished with value: 0.6483245652723093 and parameters: {'learning_rate': 0.018284840220319367, 'depth': 9, 'l2_leaf_reg': 29.332129483635, 'colsample_bylevel': 0.4545485504793926, 'min_child_samples': 85, 'bootstrap_type': 'Bernoulli', 'subsample': 0.9977319572415473}. Best is trial 14 with value: 0.6499844506443081.
# [I 2025-06-26 10:35:46,752] Trial 23 finished with value: 0.6472077831304694 and parameters: {'learning_rate': 0.01656167512395106, 'depth': 8, 'l2_leaf_reg': 25.673413900244345, 'colsample_bylevel': 0.5329638251261422, 'min_child_samples': 85, 'bootstrap_type': 'Bernoulli', 'subsample': 0.63048944144167}. Best is trial 14 with value: 0.6499844506443081.
# [I 2025-06-26 10:36:47,716] Trial 24 finished with value: 0.6419423468893102 and parameters: {'learning_rate': 0.02403702978420435, 'depth': 9, 'l2_leaf_reg': 2.990272759933241, 'colsample_bylevel': 0.4550671847671979, 'min_child_samples': 83, 'bootstrap_type': 'Bernoulli', 'subsample': 0.31559773692821647}. Best is trial 14 with value: 0.6499844506443081.
# [I 2025-06-26 10:37:49,167] Trial 25 finished with value: 0.6454847031047611 and parameters: {'learning_rate': 0.03570742077779336, 'depth': 7, 'l2_leaf_reg': 9.592329356916402, 'colsample_bylevel': 0.6000664148534998, 'min_child_samples': 31, 'bootstrap_type': 'Bernoulli', 'subsample': 0.7975825306894837}. Best is trial 14 with value: 0.6499844506443081.
# [I 2025-06-26 10:38:33,425] Trial 26 finished with value: 0.6433210570802362 and parameters: {'learning_rate': 0.056977489054475514, 'depth': 8, 'l2_leaf_reg': 0.8194720318153647, 'colsample_bylevel': 0.5210047364748687, 'min_child_samples': 62, 'bootstrap_type': 'MVS'}. Best is trial 14 with value: 0.6499844506443081.
# [I 2025-06-26 10:39:42,622] Trial 27 finished with value: 0.6286244470453848 and parameters: {'learning_rate': 0.015895747587023952, 'depth': 9, 'l2_leaf_reg': 3.5285793781899395, 'colsample_bylevel': 0.4522629266205417, 'min_child_samples': 15, 'bootstrap_type': 'Bernoulli', 'subsample': 0.4092232461755939}. Best is trial 14 with value: 0.6499844506443081.
# [I 2025-06-26 10:40:27,489] Trial 28 finished with value: 0.6483515221092083 and parameters: {'learning_rate': 0.08938089543690675, 'depth': 6, 'l2_leaf_reg': 28.374775046231516, 'colsample_bylevel': 0.866438200465909, 'min_child_samples': 77, 'bootstrap_type': 'MVS'}. Best is trial 14 with value: 0.6499844506443081.
# [I 2025-06-26 10:41:19,017] Trial 29 finished with value: 0.6475307400800843 and parameters: {'learning_rate': 0.07915989956899311, 'depth': 6, 'l2_leaf_reg': 29.3683095970184, 'colsample_bylevel': 0.8255394390666525, 'min_child_samples': 77, 'bootstrap_type': 'Bernoulli', 'subsample': 0.7809714493649297}. Best is trial 14 with value: 0.6499844506443081.
# [I 2025-06-26 10:41:40,100] Trial 30 finished with value: 0.6396723111792919 and parameters: {'learning_rate': 0.14305224388598092, 'depth': 4, 'l2_leaf_reg': 0.056300826819649874, 'colsample_bylevel': 0.7138536727131062, 'min_child_samples': 92, 'bootstrap_type': 'MVS'}. Best is trial 14 with value: 0.6499844506443081.
# [I 2025-06-26 10:42:30,987] Trial 31 finished with value: 0.6445320109948665 and parameters: {'learning_rate': 0.08240360843563181, 'depth': 7, 'l2_leaf_reg': 13.639676417940054, 'colsample_bylevel': 0.9061201264407425, 'min_child_samples': 48, 'bootstrap_type': 'MVS'}. Best is trial 14 with value: 0.6499844506443081.
# [I 2025-06-26 10:43:31,760] Trial 32 finished with value: 0.6443687421096694 and parameters: {'learning_rate': 0.03978770937985815, 'depth': 6, 'l2_leaf_reg': 13.322835738331626, 'colsample_bylevel': 0.5499206293105098, 'min_child_samples': 72, 'bootstrap_type': 'MVS'}. Best is trial 14 with value: 0.6499844506443081.
# [I 2025-06-26 10:45:11,519] Trial 33 finished with value: 0.6374708110664002 and parameters: {'learning_rate': 0.018908469297492504, 'depth': 10, 'l2_leaf_reg': 5.361271235931225, 'colsample_bylevel': 0.8737204164895631, 'min_child_samples': 53, 'bootstrap_type': 'MVS'}. Best is trial 14 with value: 0.6499844506443081.
# [I 2025-06-26 10:45:59,732] Trial 34 finished with value: 0.6466414866754419 and parameters: {'learning_rate': 0.02825056217289003, 'depth': 7, 'l2_leaf_reg': 2.157231132352254, 'colsample_bylevel': 0.5046991470547468, 'min_child_samples': 76, 'bootstrap_type': 'MVS'}. Best is trial 14 with value: 0.6499844506443081.
# [I 2025-06-26 10:46:32,914] Trial 35 finished with value: 0.637967795493777 and parameters: {'learning_rate': 0.09082805858076395, 'depth': 8, 'l2_leaf_reg': 0.9773528087453726, 'colsample_bylevel': 0.44488000604374, 'min_child_samples': 89, 'bootstrap_type': 'MVS'}. Best is trial 14 with value: 0.6499844506443081.
# [I 2025-06-26 10:47:35,194] Trial 36 finished with value: 0.6464848085991521 and parameters: {'learning_rate': 0.05495507362031685, 'depth': 6, 'l2_leaf_reg': 8.320909103595193, 'colsample_bylevel': 0.7686668678632322, 'min_child_samples': 61, 'bootstrap_type': 'MVS'}. Best is trial 14 with value: 0.6499844506443081.
# [I 2025-06-26 10:48:11,707] Trial 37 finished with value: 0.6409501499738728 and parameters: {'learning_rate': 0.12184149883656314, 'depth': 5, 'l2_leaf_reg': 16.531300226815667, 'colsample_bylevel': 0.9165388202780109, 'min_child_samples': 81, 'bootstrap_type': 'Bayesian'}. Best is trial 14 with value: 0.6499844506443081.
# [I 2025-06-26 10:49:00,732] Trial 38 finished with value: 0.6442949938535829 and parameters: {'learning_rate': 0.10711049708264936, 'depth': 10, 'l2_leaf_reg': 20.325327042927388, 'colsample_bylevel': 0.60486618989015, 'min_child_samples': 69, 'bootstrap_type': 'Bernoulli', 'subsample': 0.7979359108152239}. Best is trial 14 with value: 0.6499844506443081.
# [I 2025-06-26 10:49:28,712] Trial 39 finished with value: 0.639913650517868 and parameters: {'learning_rate': 0.19879357568406675, 'depth': 7, 'l2_leaf_reg': 3.2153153346076366, 'colsample_bylevel': 0.43298214717494854, 'min_child_samples': 32, 'bootstrap_type': 'MVS'}. Best is trial 14 with value: 0.6499844506443081.
# [I 2025-06-26 10:50:06,343] Trial 40 finished with value: 0.6459243483202923 and parameters: {'learning_rate': 0.06141430112370682, 'depth': 9, 'l2_leaf_reg': 7.867291336425358, 'colsample_bylevel': 0.47940377734762446, 'min_child_samples': 77, 'bootstrap_type': 'Bayesian'}. Best is trial 14 with value: 0.6499844506443081.
# [I 2025-06-26 10:50:49,423] Trial 41 finished with value: 0.6442542267768957 and parameters: {'learning_rate': 0.08038381836747668, 'depth': 6, 'l2_leaf_reg': 24.601201491896827, 'colsample_bylevel': 0.822409417858952, 'min_child_samples': 79, 'bootstrap_type': 'Bernoulli', 'subsample': 0.8089857780708083}. Best is trial 14 with value: 0.6499844506443081.
# [I 2025-06-26 10:51:17,630] Trial 42 finished with value: 0.6459951140308031 and parameters: {'learning_rate': 0.13576882344790042, 'depth': 6, 'l2_leaf_reg': 26.905133287335126, 'colsample_bylevel': 0.8329768492402975, 'min_child_samples': 72, 'bootstrap_type': 'Bernoulli', 'subsample': 0.8713713475234957}. Best is trial 14 with value: 0.6499844506443081.
# [I 2025-06-26 10:51:54,491] Trial 43 finished with value: 0.6466976660220439 and parameters: {'learning_rate': 0.08507490021529317, 'depth': 5, 'l2_leaf_reg': 29.129352699936614, 'colsample_bylevel': 0.8085891912509566, 'min_child_samples': 88, 'bootstrap_type': 'Bernoulli', 'subsample': 0.6988289096453106}. Best is trial 14 with value: 0.6499844506443081.
# [I 2025-06-26 10:52:44,435] Trial 44 finished with value: 0.6441200444557776 and parameters: {'learning_rate': 0.049474271465853085, 'depth': 7, 'l2_leaf_reg': 14.508205971424802, 'colsample_bylevel': 0.8783749044817992, 'min_child_samples': 67, 'bootstrap_type': 'Bernoulli', 'subsample': 0.46457098212261}. Best is trial 14 with value: 0.6499844506443081.
# [I 2025-06-26 10:53:12,521] Trial 45 finished with value: 0.6369301980745883 and parameters: {'learning_rate': 0.07170191110754054, 'depth': 5, 'l2_leaf_reg': 0.006488844700095858, 'colsample_bylevel': 0.9579762972838748, 'min_child_samples': 94, 'bootstrap_type': 'Bernoulli', 'subsample': 0.9079954260243827}. Best is trial 14 with value: 0.6499844506443081.
# [I 2025-06-26 10:53:47,869] Trial 46 finished with value: 0.6438844453089295 and parameters: {'learning_rate': 0.0949989831719428, 'depth': 6, 'l2_leaf_reg': 10.016034891253911, 'colsample_bylevel': 0.7849321311820353, 'min_child_samples': 59, 'bootstrap_type': 'MVS'}. Best is trial 14 with value: 0.6499844506443081.
# [I 2025-06-26 10:54:59,246] Trial 47 finished with value: 0.6238543951583735 and parameters: {'learning_rate': 0.011230155589306885, 'depth': 8, 'l2_leaf_reg': 0.0010735504853291533, 'colsample_bylevel': 0.7330283900193407, 'min_child_samples': 50, 'bootstrap_type': 'Bayesian'}. Best is trial 14 with value: 0.6499844506443081.
# [I 2025-06-26 10:55:55,794] Trial 48 finished with value: 0.6424740935609491 and parameters: {'learning_rate': 0.04166674127364999, 'depth': 8, 'l2_leaf_reg': 1.58224015624751, 'colsample_bylevel': 0.8526962790681986, 'min_child_samples': 38, 'bootstrap_type': 'MVS'}. Best is trial 14 with value: 0.6499844506443081.
# [I 2025-06-26 10:56:22,841] Trial 49 finished with value: 0.646332252619242 and parameters: {'learning_rate': 0.07554239408581648, 'depth': 5, 'l2_leaf_reg': 5.2032563507360825, 'colsample_bylevel': 0.48845821781542353, 'min_child_samples': 20, 'bootstrap_type': 'Bernoulli', 'subsample': 0.6950862875484565}. Best is trial 14 with value: 0.6499844506443081.
